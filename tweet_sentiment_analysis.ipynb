# %%
import pandas as pd
from twitter import *

# %%
from config import PUBLIC_KEY, PRIVATE_KEY, ACCESS_TOKEN, SECRET_TOKEN

# %%
twitter_api = Twitter(auth = OAuth(ACCESS_TOKEN, SECRET_TOKEN, PUBLIC_KEY, PRIVATE_KEY))

# %%
# test connection
twitter_api.statuses.home_timeline()
# Out:
# [{'created_at': 'Sun May 17 02:41:30 +0000 2020',
#   'id': 1261849294220529664,
#   'id_str': '1261849294220529664',
#   'text': 'Someone started talking to me tn in terms of coefficient of variation instead of Std. Dev &amp; my brain short-circuite… https://t.co/GPbBJHPVfa',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/GPbBJHPVfa',
#      'expanded_url': 'https://twitter.com/i/web/status/1261849294220529664',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri May 15 14:37:36 +0000 2020',
#   'id': 1261304729784791040,
#   'id_str': '1261304729784791040',
#   'text': 'RT @laure_wynants: Diagnosis and prognosis models we included in our systematic review in pre-print status and judged high risk of bias are…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'laure_wynants',
#      'name': 'Laure Wynants',
#      'id': 991957341724708864,
#      'id_str': '991957341724708864',
#      'indices': [3, 17]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri May 15 14:04:21 +0000 2020',
#    'id': 1261296364333531137,
#    'id_str': '1261296364333531137',
#    'text': 'Diagnosis and prognosis models we included in our systematic review in pre-print status and judged high risk of bia… https://t.co/VudZF3FUX7',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/VudZF3FUX7',
#       'expanded_url': 'https://twitter.com/i/web/status/1261296364333531137',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 991957341724708864,
#     'id_str': '991957341724708864',
#     'name': 'Laure Wynants',
#     'screen_name': 'laure_wynants',
#     'location': 'Beringen, België',
#     'description': 'Assistant Professor Epidemiology @ Maastricht University / FWO post-doc fellow @ KU Leuven / Diagnostic and prognostic modeling / Horses / Nature / Veggie',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1288,
#     'friends_count': 423,
#     'listed_count': 25,
#     'created_at': 'Thu May 03 08:27:14 +0000 2018',
#     'favourites_count': 1470,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 634,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/991962460193263616/UmHwoBHq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/991962460193263616/UmHwoBHq_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/991957341724708864/1525338002',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1261290438717300736,
#    'quoted_status_id_str': '1261290438717300736',
#    'quoted_status': {'created_at': 'Fri May 15 13:40:48 +0000 2020',
#     'id': 1261290438717300736,
#     'id_str': '1261290438717300736',
#     'text': '@MaartenvSmeden @laure_wynants You are going to like this one, reminded me of your paper. \n\n"...the model training… https://t.co/DcByHnNQOO',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MaartenvSmeden',
#        'name': 'Maarten van Smeden',
#        'id': 231008287,
#        'id_str': '231008287',
#        'indices': [0, 15]},
#       {'screen_name': 'laure_wynants',
#        'name': 'Laure Wynants',
#        'id': 991957341724708864,
#        'id_str': '991957341724708864',
#        'indices': [16, 30]}],
#      'urls': [{'url': 'https://t.co/DcByHnNQOO',
#        'expanded_url': 'https://twitter.com/i/web/status/1261290438717300736',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': 231008287,
#     'in_reply_to_user_id_str': '231008287',
#     'in_reply_to_screen_name': 'MaartenvSmeden',
#     'user': {'id': 714873918,
#      'id_str': '714873918',
#      'name': 'Iván Díaz',
#      'screen_name': 'ildiazm',
#      'location': 'New York, USA',
#      'description': 'Statistician. Asst Prof Weill Cornell Medicine. Causal inference and semiparametric estimation.',
#      'url': 'https://t.co/9rkPbAaYJ2',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/9rkPbAaYJ2',
#          'expanded_url': 'https://www.idiaz.xyz',
#          'display_url': 'idiaz.xyz',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 482,
#      'friends_count': 454,
#      'listed_count': 10,
#      'created_at': 'Tue Jul 24 20:23:30 +0000 2012',
#      'favourites_count': 354,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 412,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/2429657879/vq8ux7qvn4ljg9oh7zzu_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2429657879/vq8ux7qvn4ljg9oh7zzu_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/714873918/1541823330',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'possibly_sensitive_appealable': False,
#     'lang': 'en'},
#    'retweet_count': 3,
#    'favorite_count': 7,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1261290438717300736,
#   'quoted_status_id_str': '1261290438717300736',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri May 15 14:29:16 +0000 2020',
#   'id': 1261302635732312069,
#   'id_str': '1261302635732312069',
#   'text': "RT @Poietic_Justice: @cosgriffc @danleisman I think there's a significant difference between the parachutific effects like those reported f…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Poietic_Justice',
#      'name': 'Lukas Ronner',
#      'id': 1077956325974466560,
#      'id_str': '1077956325974466560',
#      'indices': [3, 19]},
#     {'screen_name': 'cosgriffc',
#      'name': 'C.V. Cosgriff',
#      'id': 147747982,
#      'id_str': '147747982',
#      'indices': [21, 31]},
#     {'screen_name': 'danleisman',
#      'name': 'Dan Leisman',
#      'id': 389584283,
#      'id_str': '389584283',
#      'indices': [32, 43]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri May 15 13:06:48 +0000 2020',
#    'id': 1261281881884164096,
#    'id_str': '1261281881884164096',
#    'text': "@cosgriffc @danleisman I think there's a significant difference between the parachutific effects like those reporte… https://t.co/YdFOxPzMYB",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'cosgriffc',
#       'name': 'C.V. Cosgriff',
#       'id': 147747982,
#       'id_str': '147747982',
#       'indices': [0, 10]},
#      {'screen_name': 'danleisman',
#       'name': 'Dan Leisman',
#       'id': 389584283,
#       'id_str': '389584283',
#       'indices': [11, 22]}],
#     'urls': [{'url': 'https://t.co/YdFOxPzMYB',
#       'expanded_url': 'https://twitter.com/i/web/status/1261281881884164096',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1261229897424367616,
#    'in_reply_to_status_id_str': '1261229897424367616',
#    'in_reply_to_user_id': 147747982,
#    'in_reply_to_user_id_str': '147747982',
#    'in_reply_to_screen_name': 'cosgriffc',
#    'user': {'id': 1077956325974466560,
#     'id_str': '1077956325974466560',
#     'name': 'Lukas Ronner',
#     'screen_name': 'Poietic_Justice',
#     'location': 'Philadelphia, PA',
#     'description': 'MD, MSCR | Incoming IM intern @PennMedicine by way of @IcahnMountSinai | Interested in blood cancers, trial design, med ed | Einmal ist keinmal',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 179,
#     'friends_count': 359,
#     'listed_count': 0,
#     'created_at': 'Wed Dec 26 15:56:30 +0000 2018',
#     'favourites_count': 965,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 667,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1077976329734090752/Iz7rA-GL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1077976329734090752/Iz7rA-GL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1077956325974466560/1545844585',
#     'profile_link_color': '4B0082',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri May 15 10:43:55 +0000 2020',
#   'id': 1261245921800699905,
#   'id_str': '1261245921800699905',
#   'text': 'RT @VPrasadMDMPH: .@venkmurthy notes that I like to say\n"Classic covid" when discussing covid research\nWhat do I mean by that?',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'VPrasadMDMPH',
#      'name': 'Vinay Prasad',
#      'id': 1194962714,
#      'id_str': '1194962714',
#      'indices': [3, 16]},
#     {'screen_name': 'venkmurthy',
#      'name': 'Venk Murthy',
#      'id': 25029854,
#      'id_str': '25029854',
#      'indices': [19, 30]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu May 14 20:49:47 +0000 2020',
#    'id': 1261036005747875840,
#    'id_str': '1261036005747875840',
#    'text': '.@venkmurthy notes that I like to say\n"Classic covid" when discussing covid research\nWhat do I mean by that?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'venkmurthy',
#       'name': 'Venk Murthy',
#       'id': 25029854,
#       'id_str': '25029854',
#       'indices': [1, 12]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1194962714,
#     'id_str': '1194962714',
#     'name': 'Vinay Prasad',
#     'screen_name': 'VPrasadMDMPH',
#     'location': '',
#     'description': "Doctor, Assc Prof & Sars-covi-2 expert since '17\n@Plenary_Session  \nhttps://t.co/SgeF3UpXDz",
#     'url': 'https://t.co/e8Ly3z592b',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/e8Ly3z592b',
#         'expanded_url': 'https://www.amazon.com/Malignant-Policy-Evidence-People-Cancer/dp/1421437635/',
#         'display_url': 'amazon.com/Malignant-Poli…',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/SgeF3UpXDz',
#         'expanded_url': 'http://vinayakkprasad.com/papers',
#         'display_url': 'vinayakkprasad.com/papers',
#         'indices': [68, 91]}]}},
#     'protected': False,
#     'followers_count': 42679,
#     'friends_count': 1059,
#     'listed_count': 726,
#     'created_at': 'Mon Feb 18 21:24:10 +0000 2013',
#     'favourites_count': 57199,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 2756,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1152283843950342145/GXduRFSv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1152283843950342145/GXduRFSv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1194962714/1585260123',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 19,
#    'favorite_count': 47,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 19,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri May 15 03:52:29 +0000 2020',
#   'id': 1261142382759809026,
#   'id_str': '1261142382759809026',
#   'text': 'Hi, this is your weekly reminder that there is no animal or human data that implicates IL-6 as a direct driver of any known disease.',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 32,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri May 15 03:06:18 +0000 2020',
#   'id': 1261130759529811969,
#   'id_str': '1261130759529811969',
#   'text': 'Great talk from @EDWieru !! @MayoClinicEM @MayoClinicNeuro @MayoPharmRes @MayoPCCM https://t.co/vQ43DNzpo0',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'EDWieru',
#      'name': 'Erin Wieruszewski',
#      'id': 392344828,
#      'id_str': '392344828',
#      'indices': [16, 24]},
#     {'screen_name': 'MayoClinicEM',
#      'name': 'Mayo Clinic Emergency Medicine',
#      'id': 2478804961,
#      'id_str': '2478804961',
#      'indices': [28, 41]},
#     {'screen_name': 'MayoClinicNeuro',
#      'name': 'Mayo Clinic Neuro',
#      'id': 1129503212,
#      'id_str': '1129503212',
#      'indices': [42, 58]},
#     {'screen_name': 'MayoPharmRes',
#      'name': 'Mayo Clinic Pharmacy Residency Programs',
#      'id': 1197249850800312320,
#      'id_str': '1197249850800312320',
#      'indices': [59, 72]},
#     {'screen_name': 'MayoPCCM',
#      'name': 'MayoPCCM',
#      'id': 822123302328168448,
#      'id_str': '822123302328168448',
#      'indices': [73, 82]}],
#    'urls': [{'url': 'https://t.co/vQ43DNzpo0',
#      'expanded_url': 'https://twitter.com/NorthCenSCCM/status/1260324780944826368',
#      'display_url': 'twitter.com/NorthCenSCCM/s…',
#      'indices': [83, 106]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 924796428215508993,
#    'id_str': '924796428215508993',
#    'name': 'Patrick Wieruszewski',
#    'screen_name': 'pwierusz',
#    'location': 'Rochester, MN',
#    'description': 'Cardiothoracic surgery/anesthesia ICU pharmacist & researcher @MayoClinic. Refractory shock, mechanical circulatory support, respiratory failure. Tweets my own.',
#    'url': 'https://t.co/131y0iUd4A',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/131y0iUd4A',
#        'expanded_url': 'https://www.pubmed.gov/?term=Wieruszewski%20PM%5BAuthor%5D',
#        'display_url': 'pubmed.gov/?term=Wierusze…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1063,
#    'friends_count': 1049,
#    'listed_count': 9,
#    'created_at': 'Mon Oct 30 00:33:45 +0000 2017',
#    'favourites_count': 5645,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1020,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096417527150841856/eFz_9DeY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096417527150841856/eFz_9DeY_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '9807c5c5f7a2c6ce',
#    'url': 'https://api.twitter.com/1.1/geo/id/9807c5c5f7a2c6ce.json',
#    'place_type': 'admin',
#    'name': 'Minnesota',
#    'full_name': 'Minnesota, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'contained_within': [],
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-97.239256, 43.499362],
#       [-89.483385, 43.499362],
#       [-89.483385, 49.384359],
#       [-97.239256, 49.384359]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1260324780944826368,
#   'quoted_status_id_str': '1260324780944826368',
#   'quoted_status': {'created_at': 'Tue May 12 21:43:38 +0000 2020',
#    'id': 1260324780944826368,
#    'id_str': '1260324780944826368',
#    'text': 'Need a break from COVID-19 news? \nNC Chapter of SCCM will host Erin Wieruszewski PharmD from Mayo Clinic presenting… https://t.co/nc8xa2M8RP',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/nc8xa2M8RP',
#       'expanded_url': 'https://twitter.com/i/web/status/1260324780944826368',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 973356868797063168,
#     'id_str': '973356868797063168',
#     'name': 'North Central Chapter of SCCM',
#     'screen_name': 'NorthCenSCCM',
#     'location': 'Minnesota',
#     'description': 'We are the Chapter of SCCM that covers Minnesota, Iowa, Wisconsin, North Dakota, and South Dakota',
#     'url': 'https://t.co/cUXYS8Gt0d',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/cUXYS8Gt0d',
#         'expanded_url': 'http://www.sccm.org/Member-Center/Chapters/Pages/North-Central.aspx',
#         'display_url': 'sccm.org/Member-Center/…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 24,
#     'friends_count': 18,
#     'listed_count': 0,
#     'created_at': 'Tue Mar 13 00:35:36 +0000 2018',
#     'favourites_count': 3,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 31,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/974033669831647232/gA8LLs2__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/974033669831647232/gA8LLs2__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/973356868797063168/1521062716',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 8,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Tue May 12 23:49:24 +0000 2020',
#   'id': 1260356432094007297,
#   'id_str': '1260356432094007297',
#   'text': 'RT @jmugele: I am seeing many more potential COVID patients this week here in Georgia than I was in my last week in NYC',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jmugele',
#      'name': 'Josh Mugele (He/Him)',
#      'id': 435503179,
#      'id_str': '435503179',
#      'indices': [3, 11]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 11 23:06:18 +0000 2020',
#    'id': 1259983196575449089,
#    'id_str': '1259983196575449089',
#    'text': 'I am seeing many more potential COVID patients this week here in Georgia than I was in my last week in NYC',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 435503179,
#     'id_str': '435503179',
#     'name': 'Josh Mugele (He/Him)',
#     'screen_name': 'jmugele',
#     'location': 'MX-TX-TN-CA-MI-IN-GA-???',
#     'description': 'Emergency Medicine and Disaster doctor | Program Director, building a new residency | Fascinated by humans',
#     'url': 'https://t.co/4j5GCcKHU5',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/4j5GCcKHU5',
#         'expanded_url': 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C33&q=Josh+Mugele&btnG=',
#         'display_url': 'scholar.google.com/scholar?hl=en&…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 27753,
#     'friends_count': 1515,
#     'listed_count': 132,
#     'created_at': 'Tue Dec 13 04:07:24 +0000 2011',
#     'favourites_count': 107665,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 23512,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1257844092173762561/qYzye3NU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257844092173762561/qYzye3NU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/435503179/1561910556',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 189,
#    'favorite_count': 1266,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 189,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue May 12 02:27:19 +0000 2020',
#   'id': 1260033784029704197,
#   'id_str': '1260033784029704197',
#   'text': 'RT @ArgaizR: Which of these patients has a more severe degree of venous congestion?  #VExUS Thread 🧵 about the Portal Vein (1/17) https://t…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'VExUS', 'indices': [85, 91]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ArgaizR',
#      'name': 'Eduardo R Argaiz',
#      'id': 3094231082,
#      'id_str': '3094231082',
#      'indices': [3, 11]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 11 00:09:12 +0000 2020',
#    'id': 1259636638587682826,
#    'id_str': '1259636638587682826',
#    'text': 'Which of these patients has a more severe degree of venous congestion?  #VExUS Thread 🧵 about the Portal Vein (1/17) https://t.co/x5i9uSJTBS',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'VExUS', 'indices': [72, 78]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1259563693383303168,
#       'id_str': '1259563693383303168',
#       'indices': [117, 140],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1259563693383303168/pu/img/GzNuLQXTlzTGAQIO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1259563693383303168/pu/img/GzNuLQXTlzTGAQIO.jpg',
#       'url': 'https://t.co/x5i9uSJTBS',
#       'display_url': 'pic.twitter.com/x5i9uSJTBS',
#       'expanded_url': 'https://twitter.com/ArgaizR/status/1259636638587682826/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 372, 'resize': 'fit'},
#        'medium': {'w': 848, 'h': 464, 'resize': 'fit'},
#        'large': {'w': 848, 'h': 464, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1259563693383303168,
#       'id_str': '1259563693383303168',
#       'indices': [117, 140],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1259563693383303168/pu/img/GzNuLQXTlzTGAQIO.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1259563693383303168/pu/img/GzNuLQXTlzTGAQIO.jpg',
#       'url': 'https://t.co/x5i9uSJTBS',
#       'display_url': 'pic.twitter.com/x5i9uSJTBS',
#       'expanded_url': 'https://twitter.com/ArgaizR/status/1259636638587682826/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 372, 'resize': 'fit'},
#        'medium': {'w': 848, 'h': 464, 'resize': 'fit'},
#        'large': {'w': 848, 'h': 464, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [53, 29],
#        'duration_millis': 5567,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1259563693383303168/pu/vid/848x464/Mgafr-nIcwlZziLH.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1259563693383303168/pu/pl/PzR4POoJMV0xokxI.m3u8?tag=10'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1259563693383303168/pu/vid/492x270/RR_JyZPZB-xeVanb.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3094231082,
#     'id_str': '3094231082',
#     'name': 'Eduardo R Argaiz',
#     'screen_name': 'ArgaizR',
#     'location': 'Distrito Federal, México',
#     'description': 'MD PhD. Internal Medicine @incmnszmx #DiuresisJedi #POCUS #VExUS @UNAM_MX',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3150,
#     'friends_count': 728,
#     'listed_count': 22,
#     'created_at': 'Tue Mar 17 16:16:50 +0000 2015',
#     'favourites_count': 8566,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3721,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1229662027309711360/YdaMWWp4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229662027309711360/YdaMWWp4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3094231082/1589252385',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 108,
#    'favorite_count': 232,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
# ...
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EXMXKoLWkAIilJF.jpg',
#      'url': 'https://t.co/052iZMWe5p',
#      'display_url': 'pic.twitter.com/052iZMWe5p',
#      'expanded_url': 'https://twitter.com/pwierusz/status/1257374202941845504/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 480, 'h': 342, 'resize': 'fit'},
#       'medium': {'w': 480, 'h': 342, 'resize': 'fit'},
#       'small': {'w': 480, 'h': 342, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1257374192317665282,
#      'id_str': '1257374192317665282',
#      'indices': [88, 111],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EXMXKoLWkAIilJF.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EXMXKoLWkAIilJF.jpg',
#      'url': 'https://t.co/052iZMWe5p',
#      'display_url': 'pic.twitter.com/052iZMWe5p',
#      'expanded_url': 'https://twitter.com/pwierusz/status/1257374202941845504/photo/1',
#      'type': 'animated_gif',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 480, 'h': 342, 'resize': 'fit'},
#       'medium': {'w': 480, 'h': 342, 'resize': 'fit'},
#       'small': {'w': 480, 'h': 342, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [80, 57],
#       'variants': [{'bitrate': 0,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/tweet_video/EXMXKoLWkAIilJF.mp4'}]}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 924796428215508993,
#    'id_str': '924796428215508993',
#    'name': 'Patrick Wieruszewski',
#    'screen_name': 'pwierusz',
#    'location': 'Rochester, MN',
#    'description': 'Cardiothoracic surgery/anesthesia ICU pharmacist & researcher @MayoClinic. Refractory shock, mechanical circulatory support, respiratory failure. Tweets my own.',
#    'url': 'https://t.co/131y0iUd4A',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/131y0iUd4A',
#        'expanded_url': 'https://www.pubmed.gov/?term=Wieruszewski%20PM%5BAuthor%5D',
#        'display_url': 'pubmed.gov/?term=Wierusze…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1063,
#    'friends_count': 1049,
#    'listed_count': 9,
#    'created_at': 'Mon Oct 30 00:33:45 +0000 2017',
#    'favourites_count': 5645,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1020,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096417527150841856/eFz_9DeY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096417527150841856/eFz_9DeY_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '9807c5c5f7a2c6ce',
#    'url': 'https://api.twitter.com/1.1/geo/id/9807c5c5f7a2c6ce.json',
#    'place_type': 'admin',
#    'name': 'Minnesota',
#    'full_name': 'Minnesota, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'contained_within': [],
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-97.239256, 43.499362],
#       [-89.483385, 43.499362],
#       [-89.483385, 49.384359],
#       [-97.239256, 49.384359]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1257361377670332417,
#   'quoted_status_id_str': '1257361377670332417',
#   'quoted_status': {'created_at': 'Mon May 04 17:28:07 +0000 2020',
#    'id': 1257361377670332417,
#    'id_str': '1257361377670332417',
#    'text': 'Using Mendeley for first time @pwierusz boy I wish I had converted sooner...',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'pwierusz',
#       'name': 'Patrick Wieruszewski',
#       'id': 924796428215508993,
#       'id_str': '924796428215508993',
#       'indices': [30, 39]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 716353808444612609,
#     'id_str': '716353808444612609',
#     'name': 'Dylan Barth',
#     'screen_name': 'BarthRx33',
#     'location': 'Chicago, IL',
#     'description': 'Heme/Onc Pharmacy Specialist - Northwestern Memorial Hospital || R491 || Former Mayo Clinic PGY-1 Resident || Forever Wildcats Fan || Tweets are my own',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 220,
#     'friends_count': 390,
#     'listed_count': 2,
#     'created_at': 'Sat Apr 02 19:57:12 +0000 2016',
#     'favourites_count': 517,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 542,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1197298611429793792/NIRdPWnV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1197298611429793792/NIRdPWnV_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon May 04 02:58:20 +0000 2020',
#   'id': 1257142488088883203,
#   'id_str': '1257142488088883203',
#   'text': 'RT @Poietic_Justice: Whattaya think #medtwitter, a trim and a shave before internship or nah? https://t.co/wtuBig4MJW',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'medtwitter', 'indices': [36, 47]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Poietic_Justice',
#      'name': 'Lukas Ronner',
#      'id': 1077956325974466560,
#      'id_str': '1077956325974466560',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1257102612601634817,
#      'id_str': '1257102612601634817',
#      'indices': [94, 117],
#      'media_url': 'http://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#      'url': 'https://t.co/wtuBig4MJW',
#      'display_url': 'pic.twitter.com/wtuBig4MJW',
#      'expanded_url': 'https://twitter.com/Poietic_Justice/status/1257102618154995713/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1509, 'h': 1080, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 859, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 487, 'resize': 'fit'}},
#      'source_status_id': 1257102618154995713,
#      'source_status_id_str': '1257102618154995713',
#      'source_user_id': 1077956325974466560,
#      'source_user_id_str': '1077956325974466560'}]},
#   'extended_entities': {'media': [{'id': 1257102612601634817,
#      'id_str': '1257102612601634817',
#      'indices': [94, 117],
#      'media_url': 'http://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#      'url': 'https://t.co/wtuBig4MJW',
#      'display_url': 'pic.twitter.com/wtuBig4MJW',
#      'expanded_url': 'https://twitter.com/Poietic_Justice/status/1257102618154995713/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1509, 'h': 1080, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 859, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 487, 'resize': 'fit'}},
#      'source_status_id': 1257102618154995713,
#      'source_status_id_str': '1257102618154995713',
#      'source_user_id': 1077956325974466560,
#      'source_user_id_str': '1077956325974466560'}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 389584283,
#    'id_str': '389584283',
#    'name': 'Dan Leisman',
#    'screen_name': 'danleisman',
#    'location': 'New York, NY',
#    'description': 'Incoming PGY1 @mghmedicine via @IcahnMountSinai. Cynical New Yorker. Aspiring anesthesiologist & intensivist. Sepsis, statistics, physiology, & all things ICU.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 604,
#    'friends_count': 819,
#    'listed_count': 6,
#    'created_at': 'Wed Oct 12 17:27:33 +0000 2011',
#    'favourites_count': 2560,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168313202280665088/Yj4hiZGY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389584283/1525406549',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 04 00:19:54 +0000 2020',
#    'id': 1257102618154995713,
#    'id_str': '1257102618154995713',
#    'text': 'Whattaya think #medtwitter, a trim and a shave before internship or nah? https://t.co/wtuBig4MJW',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'medtwitter', 'indices': [15, 26]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1257102612601634817,
#       'id_str': '1257102612601634817',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#       'url': 'https://t.co/wtuBig4MJW',
#       'display_url': 'pic.twitter.com/wtuBig4MJW',
#       'expanded_url': 'https://twitter.com/Poietic_Justice/status/1257102618154995713/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1509, 'h': 1080, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 859, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 487, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1257102612601634817,
#       'id_str': '1257102612601634817',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EXIgKm5WAAE3Wks.jpg',
#       'url': 'https://t.co/wtuBig4MJW',
#       'display_url': 'pic.twitter.com/wtuBig4MJW',
#       'expanded_url': 'https://twitter.com/Poietic_Justice/status/1257102618154995713/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1509, 'h': 1080, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 859, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 487, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1077956325974466560,
#     'id_str': '1077956325974466560',
#     'name': 'Lukas Ronner',
#     'screen_name': 'Poietic_Justice',
#     'location': 'Philadelphia, PA',
#     'description': 'MD, MSCR | Incoming IM intern @PennMedicine by way of @IcahnMountSinai | Interested in blood cancers, trial design, med ed | Einmal ist keinmal',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 179,
#     'friends_count': 359,
#     'listed_count': 0,
#     'created_at': 'Wed Dec 26 15:56:30 +0000 2018',
#     'favourites_count': 965,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 667,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1077976329734090752/Iz7rA-GL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1077976329734090752/Iz7rA-GL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1077956325974466560/1545844585',
#     'profile_link_color': '4B0082',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}]

# %%
# fetch a list of tweets based on a keyword

def buildTestSet(keyword):
    try:
        tweets_retrieved = twitter_api.search.tweets(q=keyword)
        print("fetched " + str(len(tweets_retrieved)) + " tweets about " + keyword)
        return [{"text":tweet.get('text')} for tweet in tweets_retrieved['statuses']]    
    except:
        print("Something went wrong...")
        return None

# %%
test_word = "tesla"

# %%
testDataSet = buildTestSet(test_word)
print(testDataSet[0:4])
# Out:
# fetched 2 tweets about tesla
# [{'text': "@KaivanShroff it's OK not to like Musk but why make stuff up? https://t.co/PQvNBGPXRi\nhttps://t.co/hKb8mhidZs\nhttps://t.co/rCvwC21gkP"}, {'text': 'RT @ChemistryReacts: Tesla coil lighting a lightbulb https://t.co/zy1y0CIt8A'}, {'text': 'RT @erickussalas: Tesla descarta a México para construir su próxima fábrica https://t.co/jOFBXxu3ri'}, {'text': 'RT @GreenlakeRun: @DonaldJTrumpJr #TakeTheRedPill! #KAG #ElonMusk #Tesla #Jobs #OpenUpAmerica @elonmusk @realDonaldTrump  @HorseShort @cact…'}]

# %%
# API to extract sentiment of tweets

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores(testDataSet[0])
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# function to request tweets within the limits set by Twitter (180 tweets/15 min)
# build a list of tweets and write them to a csv file

def buildTrainingSet(keyword, tweetDataFile):
    import csv
    import time

    sleep_time = 500
    
    trainingDataSet = []
    
    for i in range(2):
        try:
            tweets_retrieved = twitter_api.search.tweets(q=keyword, count = 90)
            print(str(len(tweets_retrieved['statuses'])) + " Tweets fetched")
            [trainingDataSet.append(tweet.get('text')) for tweet in tweets_retrieved['statuses']] 
            time.sleep(sleep_time) 
        except: 
            continue
            
    with open(tweetDataFile,'w') as csvfile:
        linewriter = csv.writer(csvfile,delimiter=',',quotechar="\"")
        for tweet in trainingDataSet:
            try:
                linewriter.writerow([tweet])
            except Exception as e:
                print(e)
    return trainingDataSet

# %%
tweetDataFile = '/Users/evanstroh/Documents/Personal/Data_science/nlp_analysis/tweetDataFile.csv'

# %%
trainingData = buildTrainingSet('remdesivir',tweetDataFile)

# %%
# run through the list of tweets to get sentiment analysis on them

positive_sentiment = 0
negative_sentiment = 0
neutral_sentiment = 0

for tweet in trainingData:
    sentiment_dict = analyzer.polarity_scores(tweet)
    print(sentiment_dict)
    if sentiment_dict.get('pos') > sentiment_dict.get('neg') and sentiment_dict.get('pos') > sentiment_dict.get('neu'):
        positive_sentiment += 1
    elif sentiment_dict.get('neg') > sentiment_dict.get('pos') and sentiment_dict.get('neg') > sentiment_dict.get('neu'):
        negative_sentiment += 1
    else: 
        neutral_sentiment += 1
# Out:
# {'neg': 0.126, 'neu': 0.777, 'pos': 0.097, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.8625}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.092, 'neu': 0.83, 'pos': 0.079, 'compound': -0.0772}
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.1007}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.128, 'neu': 0.702, 'pos': 0.169, 'compound': 0.25}
# {'neg': 0.07, 'neu': 0.733, 'pos': 0.198, 'compound': 0.541}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.8625}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.5423}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.09, 'neu': 0.91, 'pos': 0.0, 'compound': -0.2228}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.0772}
# {'neg': 0.133, 'neu': 0.683, 'pos': 0.185, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.5423}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.126, 'neu': 0.874, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.7845}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'compound': -0.2808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.836}
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.1655}
# {'neg': 0.277, 'neu': 0.598, 'pos': 0.125, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.128, 'neu': 0.702, 'pos': 0.169, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.432, 'neu': 0.568, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.165, 'neu': 0.835, 'pos': 0.0, 'compound': -0.6739}
# {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.3182}
# {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.3348}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.6124}
# {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.7906}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.8625}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.126, 'neu': 0.777, 'pos': 0.097, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.8625}
# {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'compound': 0.6581}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.092, 'neu': 0.83, 'pos': 0.079, 'compound': -0.0772}
# {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.1007}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.128, 'neu': 0.702, 'pos': 0.169, 'compound': 0.25}
# {'neg': 0.07, 'neu': 0.733, 'pos': 0.198, 'compound': 0.541}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5574}
# {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.4588}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}

# %%
# all tweet identified as having a majority of neutral sentiment

print('positive sentiment: ' + str(positive_sentiment) + '\n' + 'negative sentiment: ' + str(negative_sentiment) + '\n'
      + 'neutral sentiment: ' + str(neutral_sentiment))
# Out:
# positive sentiment: 0
# negative sentiment: 0
# neutral sentiment: 180
